# %%
import os
from sagemaker.debugger import Rule, DebuggerHookConfig, ProfilerConfig, ProfilerRule, rule_configs, FrameworkProfile
from sagemaker import get_execution_role
from sagemaker.pytorch import PyTorch

# %%
os.environ['SM_CHANNEL_TRAINING'] = 's3://lucialedezmacapstoneproject/BinImages/train'
os.environ["SM_CHANNEL_VALIDATION"] = 's3://lucialedezmacapstoneproject/BinImages/val'
os.environ["SM_CHANNEL_TEST"] = 's3://lucialedezmacapstoneproject/BinImages/test'
os.environ['SM_MODEL_DIR']='s3://lucialedezmacapstoneproject/model/'

# %%
hyperparameters =  {'batch-size':  64,  'lr':  0.009, 'model-arch':  'resnet18', 'model-n-classes': 5,  'epochs': 6}

# %%
role = get_execution_role()

estimator = PyTorch(
    entry_point='train.py',
    base_job_name='bin-images-estimator',
    role=role,
    instance_count=1,
    instance_type='ml.g4dn.xlarge',
    framework_version='1.4.0',
    py_version='py3',
    hyperparameters=hyperparameters)

# %%
estimator.fit({'training': 's3://lucialedezmacapstoneproject/BinImages/train', 
                      'test': 's3://lucialedezmacapstoneproject/BinImages/test',
                       'validation': 's3://lucialedezmacapstoneproject/BinImages/val'})
# Out:
# 2023-04-16 19:28:18 Starting - Starting the training job...
# 2023-04-16 19:28:42 Starting - Preparing the instances for trainingProfilerReport-1681673298: InProgress
# ......
# 2023-04-16 19:29:42 Downloading - Downloading input data...
# 2023-04-16 19:30:02 Training - Downloading the training image......
# 2023-04-16 19:31:03 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-16 19:31:15,009 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-16 19:31:15,040 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-16 19:31:15,043 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-16 19:31:15,211 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-16 19:31:15,211 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-16 19:31:15,211 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-16 19:31:15,212 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpuwp1mp3c/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=7943 sha256=40399754a826d5f2905019e83dfdaf4d38151e728897c41d93ad4201bbb882c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o292l4ww/wheels/39/76/ce/ecd672a32a1198d0b587067098cb39983cabc210807563094f
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2023-04-16 19:31:17,329 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 64,
#         "epochs": 6,
#         "lr": 0.009,
#         "model-arch": "resnet18",
#         "model-n-classes": 5
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "bin-images-estimator-2023-04-16-19-28-17-703",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-355502557655/bin-images-estimator-2023-04-16-19-28-17-703/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":64,"epochs":6,"lr":0.009,"model-arch":"resnet18","model-n-classes":5}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-355502557655/bin-images-estimator-2023-04-16-19-28-17-703/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":64,"epochs":6,"lr":0.009,"model-arch":"resnet18","model-n-classes":5},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bin-images-estimator-2023-04-16-19-28-17-703","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-355502557655/bin-images-estimator-2023-04-16-19-28-17-703/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch-size","64","--epochs","6","--lr","0.009","--model-arch","resnet18","--model-n-classes","5"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=64
# SM_HP_EPOCHS=6
# SM_HP_LR=0.009
# SM_HP_MODEL-ARCH=resnet18
# SM_HP_MODEL-N-CLASSES=5
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 train.py --batch-size 64 --epochs 6 --lr 0.009 --model-arch resnet18 --model-n-classes 5
# User Arguments:  {'batch_size': 64, 'test_batch_size': 1000, 'epochs': 6, 'lr': 0.009, 'model_arch': 'resnet18', 'model_n_classes': 5, 'model_dir': '/opt/ml/model', 'data_dir_training': '/opt/ml/input/data/training', 'data_dir_validation': '/opt/ml/input/data/validation', 'data_dir_test': '/opt/ml/input/data/test'}
# Epoch 0, Phase train
# [2023-04-16 19:31:20.793 algo-1:45 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-16 19:31:20.794 algo-1:45 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-16 19:31:20.794 algo-1:45 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-16 19:31:20.794 algo-1:45 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-16 19:31:20.800 algo-1:45 INFO hook.py:382] Monitoring the collections: losses
# [2023-04-16 19:31:20.800 algo-1:45 INFO hook.py:443] Hook is writing from the hook with pid: 45
# Epoch 0, Phase valid
# Epoch 1, Phase train
# Epoch 1, Phase valid
# Epoch 2, Phase train
# Epoch 2, Phase valid
# Testing Model on Whole Testing Dataset
# Testing Accuracy: 29.072561268620856, Testing Loss: 1.827670568402486
# 2023-04-16 19:34:42,566 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2023-04-16 19:35:01 Uploading - Uploading generated training model
# 2023-04-16 19:35:01 Completed - Training job completed
# Training seconds: 338
# Billable seconds: 338
